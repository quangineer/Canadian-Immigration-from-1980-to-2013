# %%
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt 
import numpy as np 

dataset = 'canada.xlsx'
df = pd.read_excel(dataset, header=20)
# clean cells
df = df.replace('..', 0)

# %%
# attempt
Total_Africa = df[df['AreaName'] == "Africa Total"]
# print(Total_Africa[1981])
print(Total_Africa.iloc[:,:])
print(Total_Africa.iloc[:,5:6])
print(Total_Africa.iloc[:,4:5])
# Out:
#          Type    Coverage      AreaName RegName  1980  1981  1982  1983  1984  \
# 6  Immigrants  Foreigners  Africa Total     NaN  3951  4363  3819  2671  2639
#
#    1985  ...   2004   2005   2006   2007   2008   2009   2010   2011   2012  \
# 6  2650  ...  28192  27523  29188  28284  29890  34534  40892  35441  38083
#
#    2013
# 6   NaN
#
# [1 rows x 38 columns]
#    1981
# 6  4363
#    1980
# 6  3951

# %%
df_bar = df
df_bar = df_bar.reset_index()

# %%
# plot bar chart

df_bar = df_bar.set_index(["AreaName", "RegName"])
# df_bar.set_index(["AreaName", "RegName"], inplace=True)
data = df_bar.iloc[1:7, 4:]

barChartData = data.T
barChartData.plot(kind='bar', layout=(5,2), subplots=True, figsize=(18, 16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11710b0f0>,
# ...
#       dtype=object)

# %%
pieChartData = df_bar.iloc[[6, 12, 17, 21, 22, 27, 28 ], 4:]
pieChartData.plot(kind='pie', y = 1990, subplots=True, figsize=(12,12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x12273afd0>],
#       dtype=object)
